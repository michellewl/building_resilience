# %%
import numpy as np
import xarray as xr
import pandas as pd
import os

import helper_functions as hf 

path = '/home/ts809/Documents/Code/github/building_resilience/top_to_bottom/'

# %%
## read EXTRAdata files:

CCs = pd.read_csv('data/help_data/UN_country_code.csv')
CCs = CCs.dropna(axis = 0).reset_index(drop=True)

WBs = pd.read_csv('data/help_data/WB_country_code.csv')
WBs = WBs.dropna(axis = 0).reset_index(drop=True)

# %%
UN_data = pd.read_csv('data/UN_data/WPP2019_TotalPopulationBySex.csv')
UN_prediction_high = hf.choose_UN_scenario(UN_data,'High')

# %%
WB_data = pd.read_csv('data/WB_WDI_data/wb_data.csv')
WB_data
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                          Afghanistan          AFG
# 2                                          Afghanistan          AFG
# 3                                          Afghanistan          AFG
# 4                                              Albania          ALB
# ...                                                ...          ...
# 1056                                               NaN          NaN
# 1057                                               NaN          NaN
# 1058                                               NaN          NaN
# 1059  Data from database: World Development Indicators          NaN
# 1060                          Last Updated: 02/27/2020          NaN
#
#                                       Series Name        Series Code  \
# 0         Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1     Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC
# 2                    Population growth (annual %)        SP.POP.GROW
# 3                               Population, total        SP.POP.TOTL
# 4         Access to electricity (% of population)     EG.ELC.ACCS.ZS
# ...                                           ...                ...
# 1056                                          NaN                NaN
# 1057                                          NaN                NaN
# 1058                                          NaN                NaN
# 1059                                          NaN                NaN
# 1060                                          NaN                NaN
#
#          1960 [YR1960]     1961 [YR1961]     1962 [YR1962]     1963 [YR1963]  \
# 0                   ..                ..                ..                ..
# 1                   ..                ..                ..                ..
# 2     1.82863870207012  1.89847565283934  1.96575051142112  2.02989338459837
# 3              8996973           9169410           9351441           9543205
# 4                   ..                ..                ..                ..
# ...                ...               ...               ...               ...
# 1056               NaN               NaN               NaN               NaN
# 1057               NaN               NaN               NaN               NaN
# 1058               NaN               NaN               NaN               NaN
# 1059               NaN               NaN               NaN               NaN
# 1060               NaN               NaN               NaN               NaN
#
#          1964 [YR1964]     1965 [YR1965]  ...     2010 [YR2010]  \
# 0                   ..                ..  ...              42.7
# 1                   ..                ..  ...                ..
# 2     2.09024767251581  2.14756657671872  ...  2.74657628012835
# 3              9744781           9956320  ...          29185507
# 4                   ..                ..  ...               100
# ...                ...               ...  ...               ...
# 1056               NaN               NaN  ...               NaN
# 1057               NaN               NaN  ...               NaN
# 1058               NaN               NaN  ...               NaN
# 1059               NaN               NaN  ...               NaN
# 1060               NaN               NaN  ...               NaN
#
#          2011 [YR2011]     2012 [YR2012]     2013 [YR2013]     2014 [YR2014]  \
# 0     43.2220189082037              69.1  70.1534805297852              89.5
# 1                   ..                ..                ..                ..
# 2     3.14312590262153  3.40758697372751  3.49458904891961  3.35558166118149
# 3             30117413          31161376          32269589          33370794
# 4                  100               100               100               100
# ...                ...               ...               ...               ...
# 1056               NaN               NaN               NaN               NaN
# 1057               NaN               NaN               NaN               NaN
# 1058               NaN               NaN               NaN               NaN
# 1059               NaN               NaN               NaN               NaN
# 1060               NaN               NaN               NaN               NaN
#
#          2015 [YR2015]     2016 [YR2016]     2017 [YR2017]     2018 [YR2018]  \
# 0                 71.5              97.7              97.7                ..
# 1                   ..                ..                ..                ..
# 2     3.07708359546317  2.77831740938728  2.54834664435549  2.38476110022344
# 3             34413603          35383128          36296400          37172386
# 4                  100               100               100                ..
# ...                ...               ...               ...               ...
# 1056               NaN               NaN               NaN               NaN
# 1057               NaN               NaN               NaN               NaN
# 1058               NaN               NaN               NaN               NaN
# 1059               NaN               NaN               NaN               NaN
# 1060               NaN               NaN               NaN               NaN
#
#      2019 [YR2019]
# 0               ..
# 1               ..
# 2               ..
# 3               ..
# 4               ..
# ...            ...
# 1056           NaN
# 1057           NaN
# 1058           NaN
# 1059           NaN
# 1060           NaN
#
# [1061 rows x 64 columns]

# %%
WB_data.loc[WB_data['Series Name'] == 'Electric power consumption (kWh per capita)'].reset_index(drop=True).iloc[217]
# Out:
# Country Name                                      Arab World
# Country Code                                             ARB
# Series Name      Electric power consumption (kWh per capita)
# Series Code                                EG.USE.ELEC.KH.PC
# 1960 [YR1960]                                             ..
#                                     ...
# 2015 [YR2015]                                             ..
# 2016 [YR2016]                                             ..
# 2017 [YR2017]                                             ..
# 2018 [YR2018]                                             ..
# 2019 [YR2019]                                             ..
# Name: 217, Length: 64, dtype: object
